# %%
import pandas as pd

# %%
sessions = ['20-21', '21-22', '22-23', '23-24', '24-25', '25-26']
history = pd.DataFrame()

# %%
def load_season_data(season):
    df = pd.read_csv(f'sportsref_download_{season}.csv')
# Out:
#       Rk  Gcar   Gtm        Date Team Unnamed: 5  Opp      Result        GS  \
# 0    1.0   1.0   1.0  23/12/2020  WAS          @  PHI  L, 107-113         *
# 1    2.0   2.0   2.0  26/12/2020  WAS        NaN  ORL  L, 120-130         *
# 2    3.0   3.0   3.0  27/12/2020  WAS        NaN  ORL  L, 113-120         *
# 3    4.0   4.0   4.0  29/12/2020  WAS        NaN  CHI  L, 107-115         *
# 4    5.0   5.0   5.0  31/12/2020  WAS        NaN  CHI  L, 130-133         *
# ..   ...   ...   ...         ...  ...        ...  ...         ...       ...
# 68  54.0   NaN  69.0  10/05/2021  WAS          @  ATL  L, 124-125  Inactive
# 69  54.0   NaN  70.0  12/05/2021  WAS          @  ATL  L, 116-120  Inactive
# 70  54.0   NaN  71.0  14/05/2021  WAS        NaN  CLE  W, 120-105  Inactive
# 71  54.0   NaN  72.0  16/05/2021  WAS        NaN  CHO  W, 115-110  Inactive
# 72   NaN   NaN   NaN         NaN  NaN        NaN  NaN       25-29        32
#
# ...

# %%
df = pd.read_csv(f'sportsref_download_20-21.csv')

# %%
df['Rk']
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
#       ...
# 68    54.0
# 69    54.0
# 70    54.0
# 71    54.0
# 72     NaN
# Name: Rk, Length: 73, dtype: float64
