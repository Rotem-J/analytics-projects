# %%
import pandas as pd
import numpy as np

# %%
def load_season_data(season):
    df = pd.read_csv(f'sportsref_download_{season}.csv', parse_dates=['Date'], dayfirst=True)
    df = df.iloc[:-1]  # Remove the last row if it's a summary or unwanted
    return df

# %%
seasons = ['20-21', '21-22', '22-23', '23-24', '24-25', '25-26']
all_seasons = [load_season_data(season) for season in seasons]
all_seasons = pd.concat(all_seasons, ignore_index=True)

# %%
all_seasons.rename(columns={
    'Unnamed: 5': 'Home/Away',
    'GS': 'Games Started',
    'Rk': 'Rank',
    'Gcar': 'Games_Career',
    'Gtm': 'Games_Team',
    'GS': 'Games_Started',
}, inplace=True)
all_seasons.loc[all_seasons['Home/Away'] == '@', 'Home/Away'] = 'Away'
all_seasons.loc[all_seasons['Home/Away'] != 'Away', 'Home/Away'] = 'Home'
all_seasons['Home/Away_num'] = np.where(all_seasons['Home/Away'] == 'Away', 0, 1)
all_seasons[['Result_type', 'Score']] = all_seasons['Result'].str.split(',', expand=True)
all_seasons[['Team_Score', 'Opponent_Score']] = all_seasons['Score'].str.split('-', expand=True)
all_seasons['Win_lose_num'] = np.where(all_seasons['Result_type'] == 'W', 1, 0)
all_seasons['Games_Started_num'] = np.where(all_seasons['Games_Started'] == '*', 1, 0)
all_seasons['Games_Started_str'] = np.where(all_seasons['Games_Started'] == '*', 'Yes', 'No')

# %%
all_seasons.to_csv('processed_seasons_data.csv', index=False)

# %%
all_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               438 non-null    float64
#  1   Games_Career       398 non-null    float64
#  2   Games_Team         438 non-null    float64
#  3   Date               438 non-null    datetime64[ns]
#  4   Team               438 non-null    object
#  5   Home/Away          438 non-null    object
#  6   Opp                438 non-null    object
#  7   Result             438 non-null    object
#  8   Games_Started      288 non-null    object
#  9   MP                 398 non-null    object
#  10  FG                 398 non-null    float64
#  11  FGA                398 non-null    float64
#  12  FG%                396 non-null    float64
#  13  3P                 398 non-null    float64
#  14  3PA                398 non-null    float64
#  15  3P%                379 non-null    float64
#  16  2P                 398 non-null    float64
#  17  2PA                398 non-null    float64
#  18  2P%                383 non-null    float64
#  19  eFG%               396 non-null    float64
#  20  FT                 398 non-null    float64
#  21  FTA                398 non-null    float64
#  22  FT%                296 non-null    float64
#  23  ORB                398 non-null    float64
#  24  DRB                398 non-null    float64
#  25  TRB                398 non-null    float64
#  26  AST                398 non-null    float64
#  27  STL                398 non-null    float64
#  28  BLK                398 non-null    float64
#  29  TOV                398 non-null    float64
#  30  PF                 398 non-null    float64
#  31  PTS                398 non-null    float64
#  32  GmSc               398 non-null    float64
#  33  +/-                397 non-null    float64
#  34  Home/Away_num      438 non-null    int64
#  35  Result_type        438 non-null    object
#  36  Score              438 non-null    object
#  37  Team_Score         438 non-null    object
#  38  Opponent_Score     438 non-null    object
#  39  Win_lose_num       438 non-null    int64
#  40  Games_Started_num  438 non-null    int64
#  41  Games_Started_str  438 non-null    object
# dtypes: datetime64[ns](1), float64(27), int64(3), object(11)
# memory usage: 143.8+ KB

# %%
pd.read_csv('processed_seasons_data.csv')
# Out:
#      Rank  Games_Career  Games_Team        Date Team Home/Away  Opp  \
# 0     1.0           1.0         1.0  2020-12-23  WAS      Away  PHI
# 1     2.0           2.0         2.0  2020-12-26  WAS      Home  ORL
# 2     3.0           3.0         3.0  2020-12-27  WAS      Home  ORL
# 3     4.0           4.0         4.0  2020-12-29  WAS      Home  CHI
# 4     5.0           5.0         5.0  2020-12-31  WAS      Home  CHI
# ..    ...           ...         ...         ...  ...       ...  ...
# 433  35.0         394.0        35.0  2026-01-02  POR      Away  NOP
# 434  36.0         395.0        36.0  2026-01-03  POR      Away  SAS
# 435  37.0         396.0        37.0  2026-01-05  POR      Home  UTA
# 436  38.0         397.0        38.0  2026-01-07  POR      Home  HOU
# 437  39.0         398.0        39.0  2026-01-09  POR      Home  HOU
#
#          Result Games_Started        MP  ...  GmSc   +/-  Home/Away_num  \
# 0    L, 107-113             *  28:06:00  ...   6.7  14.0              0
# 1    L, 120-130             *     14:40  ...   4.7  -7.0              1
# 2    L, 113-120             *  36:11:00  ...   9.1  13.0              1
# 3    L, 107-115             *  26:19:00  ...   9.7  -5.0              1
# 4    L, 130-133             *  24:32:00  ...   6.6   5.0              1
# ..          ...           ...       ...  ...   ...   ...            ...
# 433  W, 122-109             *  38:24:00  ...  32.6  14.0              0
# 434  W, 115-110             *  38:50:00  ...  25.1  10.0              0
# 435  W, 137-117             *  28:46:00  ...  30.0  23.0              1
# 436  W, 103-102             *  39:08:00  ...  27.4   0.0              1
# 437  W, 111-105             *  35:49:00  ...  13.6   3.0              1
#
#      Result_type     Score  Team_Score  Opponent_Score  Win_lose_num  \
# 0              L   107-113         107             113             0
# 1              L   120-130         120             130             0
# 2              L   113-120         113             120             0
# 3              L   107-115         107             115             0
# 4              L   130-133         130             133             0
# ..           ...       ...         ...             ...           ...
# 433            W   122-109         122             109             1
# 434            W   115-110         115             110             1
# 435            W   137-117         137             117             1
# 436            W   103-102         103             102             1
# 437            W   111-105         111             105             1
#
#      Games_Started_num  Games_Started_str
# 0                    1                Yes
# 1                    1                Yes
# 2                    1                Yes
# 3                    1                Yes
# 4                    1                Yes
# ..                 ...                ...
# 433                  1                Yes
# 434                  1                Yes
# 435                  1                Yes
# 436                  1                Yes
# 437                  1                Yes
#
# [438 rows x 42 columns]
