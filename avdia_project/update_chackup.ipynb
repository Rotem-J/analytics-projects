# %%
import pandas as pd

# %%
data = pd.read_csv('processed_seasons_data.csv')

# %%
data
# Out:
#      Rank  Games_Career  Games_Team        Date Team Home/Away  Opp  \
# 0     1.0           1.0         1.0  23/12/2020  WAS      Away  PHI
# 1     2.0           2.0         2.0  26/12/2020  WAS      Home  ORL
# 2     3.0           3.0         3.0  27/12/2020  WAS      Home  ORL
# 3     4.0           4.0         4.0  29/12/2020  WAS      Home  CHI
# 4     5.0           5.0         5.0  31/12/2020  WAS      Home  CHI
# ..    ...           ...         ...         ...  ...       ...  ...
# 435  37.0         396.0        37.0  05/01/2026  POR      Home  UTA
# 436  38.0         397.0        38.0  07/01/2026  POR      Home  HOU
# 437  39.0         398.0        39.0  09/01/2026  POR      Home  HOU
# 438   NaN           NaN         NaN  2026-02-12  POR       NaN  UTA
# 439  46.0           NaN        56.0  2026-02-12  POR      Away  UTA
#
#          Result  Games_Started             MP  ... Team_Score Opponent_Score  \
# ...
